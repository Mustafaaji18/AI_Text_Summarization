# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
import datasets
import pandas as pd
from ipywidgets import FloatProgress

# %%
data=datasets.load_dataset("id_liputan6", 'canonical', data_dir="liputan6_data",split = 'train[0:100]')

# %%
 df = pd.DataFrame(data=data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  100 non-null    object
#  1   url                 100 non-null    object
#  2   clean_article       100 non-null    object
#  3   clean_summary       100 non-null    object
#  4   extractive_summary  100 non-null    object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
df.head()
# Out:
#       id                                                url  \
# 0  26408  https://www.liputan6.com/news/read/26408/pbb-s...
# 1  26410  https://www.liputan6.com/news/read/26410/pesta...
# 2  26411  https://www.liputan6.com/news/read/26411/pk-be...
# 3  26412  https://www.liputan6.com/news/read/26412/situa...
# 4  26413  https://www.liputan6.com/news/read/26413/ratus...
#
#                                        clean_article  \
# 0  Liputan6.com, Ambon: Partai Bulan Bintang wila...
# 1  Liputan6.com, Denpasar: Berbeda dengan sebagia...
# 2  Liputan6.com, Jakarta: Partai Keadilan berteka...
# 3  Liputan6.com, Jakarta: Sekitar Rumah Makan Aya...
# 4  Liputan6.com, Jambi: Ratusan hektare sawah dik...
#
#                                        clean_summary  \
# 0  Konflik Ambon telah berlangsung selama tiga ta...
# 1  Masyarakat Bali merayakan Tahun Baru dengan tr...
# 2  Partai Keadilan menargetkan tambahan sejuta pe...
# 3  Pascaledakan granat di depan Rumah Makan Ayam ...
# ...

# %%
df.tail()
# Out:
#        id                                                url  \
# 95  26524  https://www.liputan6.com/news/read/26524/kasus...
# 96  26525  https://www.liputan6.com/news/read/26525/habib...
# 97  26526  https://www.liputan6.com/news/read/26526/presi...
# 98  26527  https://www.liputan6.com/news/read/26527/sembi...
# 99  26529  https://www.liputan6.com/news/read/26529/di-ka...
#
#                                         clean_article  \
# 95  Liputan6.com, Jakarta: Kepala Kepolisian RI Je...
# 96  Liputan6.com, Jakarta: Ruhut Sitompul, kuasa h...
# 97  Liputan6.com, Jakarta: Pejabat sementara Ketua...
# 98  Liputan6.com, Jakarta: Kinerja Wakil Rakyat di...
# 99  Liputan6.com, Berau: Akibat curah hujan yang t...
#
#                                         clean_summary  \
# 95  Tim dari Pomdam dan TNI AD telah bergabung den...
# 96  Kuasa hukum Akbar Tandjung menuding Habibie ad...
# 97  Alwi Shihab mengingatkan Presiden jangan mengh...
# ...

# %%
df
# Out:
#        id                                                url  \
# 0   26408  https://www.liputan6.com/news/read/26408/pbb-s...
# 1   26410  https://www.liputan6.com/news/read/26410/pesta...
# 2   26411  https://www.liputan6.com/news/read/26411/pk-be...
# 3   26412  https://www.liputan6.com/news/read/26412/situa...
# 4   26413  https://www.liputan6.com/news/read/26413/ratus...
# ..    ...                                                ...
# 95  26524  https://www.liputan6.com/news/read/26524/kasus...
# 96  26525  https://www.liputan6.com/news/read/26525/habib...
# 97  26526  https://www.liputan6.com/news/read/26526/presi...
# 98  26527  https://www.liputan6.com/news/read/26527/sembi...
# 99  26529  https://www.liputan6.com/news/read/26529/di-ka...
#
#                                         clean_article  \
# 0   Liputan6.com, Ambon: Partai Bulan Bintang wila...
# 1   Liputan6.com, Denpasar: Berbeda dengan sebagia...
# 2   Liputan6.com, Jakarta: Partai Keadilan berteka...
# ...

# %%
df.count()
# Out:
# id                    100
# url                   100
# clean_article         100
# clean_summary         100
# extractive_summary    100
# dtype: int64

# %%
print(df.shape)
# Out:
# (100, 5)

# %%
print(df.size)
# Out:
# 500

# %%
print(df.ndim)
# Out:
# 2

# %%
df.describe()
# Out:
#            id                                                url  \
# count     100                                                100
# unique    100                                                100
# top     26408  https://www.liputan6.com/news/read/26408/pbb-s...
# freq        1                                                  1
#
#                                             clean_article  \
# count                                                 100
# unique                                                100
# top     Liputan6.com, Ambon: Partai Bulan Bintang wila...
# freq                                                    1
#
#                                             clean_summary  \
# count                                                 100
# unique                                                100
# top     Konflik Ambon telah berlangsung selama tiga ta...
# freq                                                    1
#
# ...

# %%
df.sample()
# Out:
#        id                                                url  \
# 65  26487  https://www.liputan6.com/news/read/26487/infla...
#
#                                         clean_article  \
# 65  Liputan6.com, Jakarta: Tingkat inflasi tahun k...
#
#                                         clean_summary  \
# 65  Inflasi tahun kalender 2001 mencapai 12, 55 pe...
#
#                                    extractive_summary
# 65  Liputan6.com, Jakarta: Tingkat inflasi tahun k...

# %%
duplicates=df.duplicated( )
duplicates.sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# id                    object
# url                   object
# clean_article         object
# clean_summary         object
# extractive_summary    object
# dtype: object

# %%
na=df.isna( )
na.sum()
# Out:
# id                    0
# url                   0
# clean_article         0
# clean_summary         0
# extractive_summary    0
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.memory_usage()
# Out:
# Index                 128
# id                    800
# url                   800
# clean_article         800
# clean_summary         800
# extractive_summary    800
# dtype: int64

# %%
df.nunique( )
# Out:
# id                    100
# url                   100
# clean_article         100
# clean_summary         100
# extractive_summary    100
# dtype: int64

# %%
def clean_title(text):
   text = "".join([word.lower() for word in text if word not in string.punctuation])
   title = re.split('\W+', text)
   text = [ps.stem(word) for word in title if word not in nltk.corpus.stopwords.words('english')]
   return text
count_vectorize = CountVectorizer(analyzer=clean_title)
vectorized = count_vectorize.fit_transform(news['title'])
